# %%
from IPython.display import Image
Image(filename='Top-10-Best-Anime-Series-Of-All-Time-Ranked-1140x570.jpg', width=1000, height=8)

# %% [markdown]
# # Anime Articles

# %% [markdown]
# ## Table of Contents
#
# 1. [Project Overview](#1.-Project-Overview)
# 3. [Importing Packages](#2.-Importing-Packages)
# 4. [Loading Data](#3.-Loading-Data)
# 5. [Data Cleaning and Filtering](#4.-Data-Cleaning-and-Filtering)
# 6. [Exploratory Data Analysis (EDA)](#5.-Exploratory-Data-Analysis-(EDA))
# 7. [Model Training and Evaluation](#6.-Model-Training-and-Evaluation)
# 8. [Conclusion & Insights](#7.-Conclusion-&-Insights)
# 9. [References](#8.-References)

# %% [markdown]
# ## 1. Project Overview

# %% [markdown]
# ## 2. Importing Packages

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import os
from IPython.display import Image
import re
import mlflow
import mlflow.sklearn
import time
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.pipeline import make_pipeline
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# %% [markdown]
# ## 3. Loading data

# %% [markdown]
# ## 4. Data Cleaning and Filtering

# %% [markdown]
# ## 5. Exploratory Data Analysis (EDA)

# %% [markdown]
# ## 6. Model Training and Evaluation

# %% [markdown]
# ## 7. Conclusion & Insights

# %% [markdown]
# ## 8. References
